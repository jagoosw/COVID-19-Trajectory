# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from numpy import ma
np.seterr(invalid='ignore')

deaths=pd.read_csv("deaths_new.csv")

deaths_old=deaths.drop(deaths.index[260-7:])
average_period=7
total_deaths=deaths.cumsum(axis=0)
rolling_average=deaths.rolling(average_period).mean()

average_period=30

average_deaths=pd.read_csv("5YearDeaths.csv")
average_deaths.loc[:,'Total'] = average_deaths.sum(axis=1)
average_deaths['Rolling Average'] = average_deaths['Total'].rolling(average_period).mean()
average_deaths['Rolling ST Dev'] = average_deaths['Total'].rolling(average_period).std()
average_deaths['Rolling ST Dev 30 Before'] = average_deaths['Total'].rolling(average_period).std().shift(average_period)
average_deaths['Rolling ST Dev ratio']=average_deaths["Rolling ST Dev"]/average_deaths["Rolling ST Dev 30 Before"]

# %%
plt.plot(np.divide(average_deaths["Rolling Average"].astype(str).astype(float).to_numpy(),668))

plt.plot([122,122],[0,2.5])
plt.plot([218-6,218-6],[0,2.5])
plt.plot([122-31,122-31],[0,2.5])

plt.xlabel("Day (starting $1^{st}$ August)")
plt.ylabel("30 moving average deaths from all causes")
plt.title("Moving average deaths per hundred thousand from all causes, 5 year average [ONS,2019]")
plt.legend(["Moving average deaths per hundred thousand","Start of winter excess mortality ($1^{st}$ December) - coincides with a doubling of 30 day standard deviation change","End of winter excess mortality ($1^{st}$ March) - coincides with a halfing of 30 day standard deviation change","Today (29/10/2020)"])

# %%
non_winter_average_deaths=1378
prop_of_covid_would_be_winter=.5
winter_mortality=average_deaths.drop(average_deaths.index[:122-30-30-23]).drop(average_deaths.index[122-30-30-23+51:])
winter_mortality["Excess"]=winter_mortality["Rolling Average"]-non_winter_average_deaths+114-1.366667+32-30
winter_mortality["Excess Adjusted"]=winter_mortality["Excess"].apply(lambda x : x -x*prop_of_covid_would_be_winter*total_deaths["United Kingdom"][260-7]/winter_mortality["Excess"].sum()) 
total_winter_mortality=winter_mortality.cumsum(axis=0)
print(winter_mortality)
# Out:
#           Date  Five-year average daily deaths  \
# 39  09/09/2018                            1186
# 40  10/09/2018                            1186
# 41  11/09/2018                            1183
# 42  12/09/2018                            1188
# 43  13/09/2018                            1236
# 44  14/09/2018                            1203
# 45  15/09/2018                            1211
# 46  16/09/2018                            1235
# 47  17/09/2018                            1203
# 48  18/09/2018                            1233
# 49  19/09/2018                            1195
# 50  20/09/2018                            1223
# 51  21/09/2018                            1228
# 52  22/09/2018                            1241
# 53  23/09/2018                            1215
# 54  24/09/2018                            1233
# 55  25/09/2018                            1243
# 56  26/09/2018                            1227
# 57  27/09/2018                            1241
# ...

# %%
plt.rcParams["figure.figsize"] = (16,9)

#plt.plot((np.divide(deaths["United Kingdom"].drop(deaths.index[260-7:]).cumsum(axis=0).astype(str).astype(int).to_numpy(),668)),(np.divide(rolling_average["United Kingdom"].drop(deaths.index[260-7:]).astype(str).astype(float).to_numpy(),668)))
plt.plot((np.divide(rolling_average["United Kingdom"].drop(deaths.index[0:260-7]).astype(str).astype(float).to_numpy(),1)))
#plt.plot(np.log10(total_deaths["Italy"].astype(str).astype(int).to_numpy()),np.log10(rolling_average["Italy"].astype(str).astype(float).to_numpy()))
#plt.plot(np.log10(total_deaths_recent["Italy"].astype(str).astype(int).to_numpy()),np.log10(rolling_average_recent["Italy"].astype(str).astype(float).to_numpy()))
#plt.plot(np.log10(total_deaths["France"].astype(str).astype(int).to_numpy()),np.log10(rolling_average["France"].astype(str).astype(float).to_numpy()))
#plt.plot(np.log10(total_deaths_recent["France"].astype(str).astype(int).to_numpy()),np.log10(rolling_average_recent["France"].astype(str).astype(float).to_numpy()))

#plt.plot((np.divide(total_deaths["Germany"].drop(deaths.index[260-7:]).astype(str).astype(int).to_numpy(),839)),(np.divide(rolling_average["Germany"].drop(deaths.index[260-7:]).astype(str).astype(float).to_numpy(),839)))
#plt.plot((np.divide(deaths["Germany"].drop(deaths.index[0:260-7]).cumsum(axis=0).astype(str).astype(int).to_numpy(),839)),(np.divide(rolling_average["Germany"].drop(deaths.index[0:260-7]).astype(str).astype(float).to_numpy(),839)))

china_dip=110
#plt.plot((np.divide(total_deaths["China"].drop(deaths.index[china_dip-7:]).astype(str).astype(float).to_numpy(),14409)),(np.divide(rolling_average["China"].drop(deaths.index[china_dip-7:]).astype(str).astype(float).to_numpy(),14409)))
#plt.plot((np.divide(deaths["China"].drop(deaths.index[0:china_dip-7]).cumsum(axis=0).astype(str).astype(float).to_numpy(),14409)),(np.divide(rolling_average["China"].drop(deaths.index[0:china_dip-7]).astype(str).astype(float).to_numpy(),14409)))

#plt.plot((np.divide(total_deaths["United Kingdom"][86],668)),(np.divide(rolling_average["United Kingdom"][86],668)),color="red",marker="o")
#plt.plot((np.divide(deaths["United Kingdom"].drop(deaths.index[0:260-7]).cumsum(axis=0)[286],1)),(np.divide(rolling_average_recent["United Kingdom"][286],1)),color="blue",marker="o")

plt.plot((np.divide(winter_mortality["Excess"].astype(str).astype(float).to_numpy(),1)),linestyle = '--')
#plt.plot((np.divide(total_winter_mortality["Excess Adjusted"].astype(str).astype(float).to_numpy(),668)),(np.divide(winter_mortality["Excess Adjusted"].astype(str).astype(float).to_numpy(),668)),linestyle = '--')


#plt.xscale('log')
#plt.yscale('log')
plt.xlabel("$\log_{10}$ Total deaths per hundred thousand")
plt.ylabel("$\log_{10}$ 7 day deaths per hundred thousand rolling average")

plt.legend(["United Kingdom","5 year average of 'winter' mortality, derived from all cause mortality minus background mortality rate from rest of year","UK Lockdown Start","UK Tier System Introduction","UK Average Winter Excess Mortality for this period"])#,"Italy","Italy Second Wave","France","France Second Wave"])"""

# %%
plt.rcParams["figure.figsize"] = (16,9)

#plt.plot((np.divide(deaths["United Kingdom"].drop(deaths.index[260-7:]).cumsum(axis=0).astype(str).astype(int).to_numpy(),668)),(np.divide(rolling_average["United Kingdom"].drop(deaths.index[260-7:]).astype(str).astype(float).to_numpy(),668)))
plt.plot((np.divide(rolling_average["United Kingdom"].drop(deaths.index[0:260-7]).astype(str).astype(float).to_numpy(),1)))
#plt.plot(np.log10(total_deaths["Italy"].astype(str).astype(int).to_numpy()),np.log10(rolling_average["Italy"].astype(str).astype(float).to_numpy()))
#plt.plot(np.log10(total_deaths_recent["Italy"].astype(str).astype(int).to_numpy()),np.log10(rolling_average_recent["Italy"].astype(str).astype(float).to_numpy()))
#plt.plot(np.log10(total_deaths["France"].astype(str).astype(int).to_numpy()),np.log10(rolling_average["France"].astype(str).astype(float).to_numpy()))
#plt.plot(np.log10(total_deaths_recent["France"].astype(str).astype(int).to_numpy()),np.log10(rolling_average_recent["France"].astype(str).astype(float).to_numpy()))

#plt.plot((np.divide(total_deaths["Germany"].drop(deaths.index[260-7:]).astype(str).astype(int).to_numpy(),839)),(np.divide(rolling_average["Germany"].drop(deaths.index[260-7:]).astype(str).astype(float).to_numpy(),839)))
#plt.plot((np.divide(deaths["Germany"].drop(deaths.index[0:260-7]).cumsum(axis=0).astype(str).astype(int).to_numpy(),839)),(np.divide(rolling_average["Germany"].drop(deaths.index[0:260-7]).astype(str).astype(float).to_numpy(),839)))

china_dip=110
#plt.plot((np.divide(total_deaths["China"].drop(deaths.index[china_dip-7:]).astype(str).astype(float).to_numpy(),14409)),(np.divide(rolling_average["China"].drop(deaths.index[china_dip-7:]).astype(str).astype(float).to_numpy(),14409)))
#plt.plot((np.divide(deaths["China"].drop(deaths.index[0:china_dip-7]).cumsum(axis=0).astype(str).astype(float).to_numpy(),14409)),(np.divide(rolling_average["China"].drop(deaths.index[0:china_dip-7]).astype(str).astype(float).to_numpy(),14409)))

#plt.plot((np.divide(total_deaths["United Kingdom"][86],668)),(np.divide(rolling_average["United Kingdom"][86],668)),color="red",marker="o")
#plt.plot((np.divide(deaths["United Kingdom"].drop(deaths.index[0:260-7]).cumsum(axis=0)[286],1)),(np.divide(rolling_average_recent["United Kingdom"][286],1)),color="blue",marker="o")

plt.plot((np.divide(winter_mortality["Excess"].astype(str).astype(float).to_numpy(),1)),linestyle = '--')
#plt.plot((np.divide(total_winter_mortality["Excess Adjusted"].astype(str).astype(float).to_numpy(),668)),(np.divide(winter_mortality["Excess Adjusted"].astype(str).astype(float).to_numpy(),668)),linestyle = '--')


#plt.xscale('log')
#plt.yscale('log')
plt.xlabel("Days since 9th September 2020")
plt.ylabel("7 day rolling average of deaths")
plt.title("UK $2^{nd}$ wave COVID-19 deaths and usual winter excess deaths")

plt.legend(["United Kingdom","5 year average of 'winter' mortality, derived from all cause mortality minus background mortality rate from rest of year","UK Lockdown Start","UK Tier System Introduction","UK Average Winter Excess Mortality for this period"])#,"Italy","Italy Second Wave","France","France Second Wave"])"""

# %%
print(np.divide(deaths["United Kingdom"].drop(deaths.index[260-7:]).cumsum(axis=0).astype(str).astype(int).to_numpy(),668))
# Out:
# [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
# ...

# %%
print(total_deaths["United Kingdom"])
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#        ...
# 299    44745
# 300    44896
# 301    44998
# 302    45365
# 303    45675
# Name: United Kingdom, Length: 304, dtype: object
